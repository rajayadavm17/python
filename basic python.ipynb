# %% [markdown]
# <a href="https://colab.research.google.com/github/rajayadavm17/python/blob/main/basic%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_id = 100
print(student_id)
# Out:
# 100

# %%
$tudent_id = 100
print(student_id)
# Out:
#   File "/tmp/ipykernel_8258/666015208.py", line 1
#     $tudent_id = 100
#     ^
# SyntaxError: invalid syntax

# %%
student_id124 = 100
print(student_id)
# Out:
# 100

# %%
12student_id = 100
print(student_id)
# Out:
#   File "/tmp/ipykernel_8258/1809523332.py", line 1
#     12student_id = 100
#      ^
# SyntaxError: invalid decimal literal

# %%
student_id = 100
print(student_id)
# Out:
# 100

# %%
student_id = 100
print(Student_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8258/289958673.py in <cell line: 0>()
#       1 student_id = 100
# ----> 2 print(Student_id)
#
# NameError: name 'Student_id' is not defined

# %%
_student_id = 100
print(_student_id)
# Out:
# 100

# %%
if = 100
print(if)
# Out:
#   File "/tmp/ipykernel_8258/1194631722.py", line 1
#     if = 100
#        ^
# SyntaxError: invalid syntax

# %%
def = 100
print(def)
# Out:
#   File "/tmp/ipykernel_8258/64999760.py", line 1
#     def = 100
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ***variables***

# %%
value = 10
print(value)
# Out:
# 10

# %%
a = 1000
print(" the total mangoes are :",a)
# Out:
#  the total mangoes are : 1000

# %%
a,b,c=10,20,30
print(b)
print(c)
print(a)
# Out:
# 20
# 30
# 10

# %%
a,b,c=10,20,30,40
print(b)
print(c)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4392/1881994392.py in <cell line: 0>()
# ----> 1 a,b,c=10,20,30,40
#       2 print(b)
#       3 print(c)
#       4 print(a)
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
sal = 20000
print("my salary is :",sal)
# Out:
# my salary is : 20000

# %%
sal = 20000
sal = 50000
print("my salary is :",sal)
# Out:
# my salary is : 50000

# %% [markdown]
# ### ***data types***

# %%
emp_id = 100
name = "ram"
sal  = 100000.00
print(emp_id)
print(name)
print(sal)
print("my employee id is:",emp_id)
print("my name is: ", name)
print("my salary is :",sal)
print("type of employe id is:", type(emp_id))
print("type of name is :",type(name))
print("type of sal is :",type(sal))
# Out:
# 100
# ram
# 100000.0
# my employee id is: 100
# my name is:  ram
# my salary is : 100000.0
# type of employe id is: <class 'int'>
# type of name is : <class 'str'>
# type of sal is : <class 'float'>
